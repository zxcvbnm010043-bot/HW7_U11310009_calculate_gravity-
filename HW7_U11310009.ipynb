# %%
import numpy as np

# %%
import glob

# %%
lon= 12.1878; lat= 48.1195; ele= 487.9; g0 = 980717.39

# %%
# 觀測重力值
Ge = 978031.35

# %%
np.pi
# Out:
# 3.141592653589793

# %%
lat = 48.1195

# %%
lat_r = lat * np.pi / 180
lat_r
# Out:
# 0.8398437094134115

# %%
np.sin(lat_r)
# Out:
# np.float64(0.7445387927201025)

# %%
# 理論重力值
Gt = Ge*(1 + 0.0052788895 * np.sin(lat_r) ** 2 + 0.000023462 * np.sin(lat_r) ** 4)
Gt
# Out:
# np.float64(980900.4037658547)

# %%
# 自由空間校正
FAC = ele * 0.308  
FAC
# Out:
# 150.2732

# %%
# 布蓋校正
BC = 0.112 * ele
BC
# Out:
# 54.6448

# %%
# 自由空間校正
Delta_Gfa = Ge+FAC
print(Delta_Gfa)
# Out:
# 977881.0767999999

# %%
# 布蓋重力校正
Delta_Gbc = Ge - BC + FAC
print(Delta_Gbc)
# Out:
# 978126.9784
